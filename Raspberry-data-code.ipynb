# %% [markdown]
# <a href="https://colab.research.google.com/github/Mattbrake951/Rspberry-Shake-data/blob/main/Raspberry-data-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to the Colab Notebook
#
# This Notebook will be used for downloading data from Raspberry Shake.
#
# To get started, Run the code line below to import and install the required package for this activity - Obspy
#
# To run the code, click on the ![image.png](data:image/png;base64,...) icon. Note the download may take a moment.

# %%
try:
  import obspy
except:
  # !pip install obspy

# %% [markdown]
# # Restart Runtime
#
# After installing obspy, you need to restart the runtime. Select the "Runtime" menu, and select "Restart runtime".
#
# (This is due to a subtlety of how Google Colab works)

# %% [markdown]
# # Downloading Data!
#
# In the code below you will see a 'obspy.read()' and a 'stream.plot()' functions. these read in the data from a file and plots it.
#
# To get to these files. open the link https://drive.google.com/drive/folders/1JAzAC9LspwQQPZkC_BoCjd-XNmitJXFs?usp=sharing and download a chosen file.
#
# Once downloaded, click on the file space in colab located on the left with the icon ![image.png](data:image/png;base64,...) . You can simply drag and drop the file you just downloded into the file space underneath ![image.png](data:image/png;base64,...) . Once downloaded, change the name within the brackets of the 'obspy.read()' function to the name of the file you just downloaded and run the code.
#
# You should then see a plot of the data.

# %%
stream=obspy.read('filename')
stream.plot()
# Out:
# file already downloaded to Colab files
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bcc3e154a9f8> in <module>()
#       5   print('file already downloaded to Colab files')
#       6
# ----> 7 stream=obspy.read('query.mseed')
#       8 stream.plot()
#
# <decorator-gen-145> in read(pathname_or_url, format, headonly, starttime, endtime, nearest_sample, dtype, apply_calib, check_compression, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/obspy/core/util/decorator.py in _map_example_filename(func, *args, **kwargs)
#     298                         except IOError:
#     299                             pass
# --> 300         return func(*args, **kwargs)
#     301     return _map_example_filename
#     302
#
# ...

# %%
import os
if not os.path.isfile('query (1)'):
  # !wget https://drive.google.com/drive/folders/1JAzAC9LspwQQPZkC_BoCjd-XNmitJXFs?usp=sharing
else:
  print('file already downloaded to Colab files')

#stream=obspy.read('query (1)')
#stream.plot()
# Out:
# --2022-02-28 19:30:49--  https://drive.google.com/drive/folders/1JAzAC9LspwQQPZkC_BoCjd-XNmitJXFs?usp=sharing
# Resolving drive.google.com (drive.google.com)... 74.125.124.102, 74.125.124.138, 74.125.124.113, ...
# Connecting to drive.google.com (drive.google.com)|74.125.124.102|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘1JAzAC9LspwQQPZkC_BoCjd-XNmitJXFs?usp=sharing.1’
#
# 1JAzAC9LspwQQPZkC_B     [ <=>                ] 201.83K  --.-KB/s    in 0.09s
#
# 2022-02-28 19:30:49 (2.21 MB/s) - ‘1JAzAC9LspwQQPZkC_BoCjd-XNmitJXFs?usp=sharing.1’ saved [206669]
